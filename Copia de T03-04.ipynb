# %% [markdown]
# # Ejercicio
#
# Vamos a pedirle al usuario palabras o frases y le vamos a devolver el mismo string modificado con alguno de los métodos aprendidos según se indique:
#
# 1. Devolver la palabra en mayúscula
# 2. Devolver la frase con todas las palabras empezando en mayúscula
# 3. Devolver la palabra (con 3 o más letras) con todas las letras en minúscula salvo la tercera letra
# 4. Devolver la palabra con todas las letras en mayúsculas salvo la primera y la última
# 5. Devolver la frase donde cada vez que aparezcan las dos primeras letras de la primera palabra, sean substituidas por cualesquiera otras dos letras.

# %% [markdown]
# ## Apartado 1

# %%
frase = input("Escriba la frase o palabra que desee: ")
print(frase.upper())
# Out:
# Escriba la frase o palabra que desee: hola soy santiago
# HOLA SOY SANTIAGO

# %% [markdown]
# ## Apartado 2

# %%
frase = input("Escriba la frase o palabra que desee: ")
print(frase.title())
# Out:
# Escriba la frase o palabra que desee: hola soy santiago
# Hola Soy Santiago

# %% [markdown]
# ## Apartado 3

# %%
frase = input("Escriba la frase o palabra que desee: ")
print(frase[:2].lower() + frase[2].upper() + frase[3:])
# Out:
# Escriba la frase o palabra que desee: como
# coMo

# %% [markdown]
# ## Apartado 4

# %%
frase = input("Escriba la frase o palabra que desee: ")
print(frase[0].lower() + frase[1:len(frase)-1].upper() + frase[-1].lower())
# Out:
# Escriba la frase o palabra que desee: hola
# hOLa

# %% [markdown]
# ## Apartado 5

# %%
frase = input("Escriba la frase o palabra que desee: ")
pal_cambio = input("Ingrese las dos letras nuevas: ")
print(frase.replace(frase[0:2], pal_cambio))
# Out:
# Escriba la frase o palabra que desee: hola
# Ingrese las dos letras nuevas: ua
# uala
