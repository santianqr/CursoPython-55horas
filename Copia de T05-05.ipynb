# %% [markdown]
# # Ejercicio
#
# Vamos a recorrer un string dado con un bucle `for` y lo vamos a devolver impreso del revés.

# %%
s = "se van sus naves"
s_inv = ""

for c in s:
  s_inv = c + s_inv

print(s_inv)
# Out:
# sevan sus nav es
