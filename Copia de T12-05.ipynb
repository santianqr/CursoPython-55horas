# %% [markdown]
# # Ejercicio
#
# Vamos a cargar un csv desde una [url](https://gist.githubusercontent.com/jncraton/68beb88e6027d9321373/raw/381dcf8c0d4534d420d2488b9c60b1204c9f4363/starwars.csv) y a continuación vamos a eliminar todos los valores `NA`.

# %%
import pandas as pd
sw = pd.read_csv("https://gist.githubusercontent.com/jncraton/68beb88e6027d9321373/raw/381dcf8c0d4534d420d2488b9c60b1204c9f4363/starwars.csv")

# %%
sw.head()
# Out:
#    SetID Number  Variant  ... Owned Wanted  QtyOwned
# 0   5860  10179        1  ...    No     No         0
# 1   6522  10188        1  ...    No     No         0
# 2   4799  10143        1  ...    No     No         0
# 3  23529  75059        1  ...    No     No         0
# 4   8733  10221        1  ...    No     No         0
#
# [5 rows x 17 columns]

# %%
sw.shape
# Out:
# (508, 17)

# %%
sw = sw.dropna()

# %%
sw.shape
# Out:
# (155, 17)
