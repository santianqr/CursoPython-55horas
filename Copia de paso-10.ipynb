# %% [markdown]
# # Paso 10
#
# Añade la validación de que el jugador tiene las fichas necesarias para formar la palabra. Para ello:
# * En la clase `Board` crea el método `.getPawns()` que recibe la palabra a colocar `word`, las coordenadas (`x`, `y`) y la dirección `direction` y devuelve un objeto de la clase `Word` con las fichas que faltan en el tablero para formar esa palabra.
# * En el programa principal `main`, comprueba que el jugador dispone de las fichas que devuelve el método `.getPawns()` comparando la tabla de frecuencias de las fichas del jugador con la tabla de frecuencias de las fichas necesarias.
# * Recuerda que puedes usar el método `.isSubset()` de la clase `FrequencyTable`.
