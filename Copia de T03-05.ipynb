# %% [markdown]
# # Ejercicio
#
# Vamos a pedirle al usuario su año de nacimiento y el año actual y le vamos a imprimir por pantalla su edad

# %%
b_year = int(input("Digite su año de nacimiento: "))
c_year = int(input("Digite el año actual: "))
print("Su edad actual es {} años".format(c_year - b_year))
# Out:
# Digite su año de nacimiento: 1998
# Digite el año actual: 2021
# Su edad actual es 23 años
