# %% [markdown]
# # Paso 7
#
# Crea la clase `Board` en el script `ApylabradosModule.py`
#
# * Configura el constructor para que contenga los siguientes atributos:
#     * una variable `board` que contenga un array bidimensional de 15 x 15 caracteres los cuales inicialmente son `" "`
#     * una variable `totalWords` que contenga un entero con el número de palabras colocadas en el tablero y que inicialmente vale 0
#     * una variable `totalPawns` que contenga un entero con el número de fichas colocadas en el tablero y que inicialmente vale 0.
# * Construye el método `.showBoard()` que muestre el tablero de 15 x 15
# * En el notebook `main` crea un objeto de la clase `Board` y muéstralo por pantalla con `.showBoard()`

# %%
class Board:
    
    def __init__(self):
        board = [["A"] * 15] * 15
        self.board = board
        self.totalWords = 0
        self.totalPawns = 0
    

    def showBoard(self):
        count_row = 0
        
        for i in range(len(self.board) * 2 + 2):
            
            if i == 0:
                for j in range(len(self.board)):
                    print("  {}".format('0'+str(j) if j < 10 else str(j)), end = '')
                print()
            
            elif i % 2 == 0 :
                for j in range(len(self.board)):
                    if j == len(self.board) -1:
                        print("| {} | {}".format(self.board[count_row][j], '0'+str(count_row) if count_row < 10 else str(count_row) ), end = "")
                    else:
                        print("| {} ".format(self.board[count_row][j]), end = "")
                count_row += 1
                print()
            
            else:
                print("+---"*15)

# %%
Board().board
# Out:
# [['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
#  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'],
# ...

# %%
Board().showBoard()
# Out:
#   00  01  02  03  04  05  06  07  08  09  10  11  12  13  14
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 00
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 01
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 02
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 03
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 04
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 05
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# | A | A | A | A | A | A | A | A | A | A | A | A | A | A | A | 06
# ...
