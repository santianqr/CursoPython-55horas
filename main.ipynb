# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/scripts
# Out:
# /content/drive/MyDrive/Colab Notebooks/scripts

# %%
import ApylabradosModule

# %%
bag_of_pawns = ApylabradosModule.Pawns()
player_pawns = ApylabradosModule.Pawns()

# %%
bag_of_pawns.createBag()

# %%
for _ in range(7):
    player_pawns.addPawn(bag_of_pawns.takeRandomPawn())
player_pawns.showPawns()
# Out:
# D: 1
# E: 3
# O: 1
# R: 1
# T: 1

# %%
new_word = ApylabradosModule.Word.readWord()
ApylabradosModule.Dictionary.validateWord(new_word)
# Out:
# hi
# True

# %%
player_pawns_freq = player_pawns.getFrequency()
player_pawns_freq.showFrequency()
# Out:
# D: 1
# E: 3
# O: 1
# R: 1
# T: 1

# %%
new_word_freq = new_word.getFrequency()
new_word_freq.showFrequency()
# Out:
# H: 1
# I: 1

# %%
ApylabradosModule.FrequencyTable.isSubset(new_word_freq, player_pawns_freq)
# Out:
# False

# %%
board = ApylabradosModule.Board()

# %%
x = int(input())
y = int(input())
new_word = ApylabradosModule.Word.readWord()
dir = input()
board.placeWord(player_pawns, new_word, x, y, dir)
board.showBoard()

player_pawns.showPawns()
print(player_pawns.getTotalPawns())
while(player_pawns.getTotalPawns() < 7):
  player_pawns.addPawn(bag_of_pawns.takeRandomPawn())

player_pawns.showPawns()
print(player_pawns.getTotalPawns())
print(board.totalPawns)
print(board.totalWords)
# Out:
# 5
# 8
# EIOS
# V
#   00  01  02  03  04  05  06  07  08  09  10  11  12  13  14
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   | 00
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   | 01
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   | 02
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   | 03
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   | 04
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   | T | O | R | E |   |   |   |   |   |   | 05
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---
# |   |   |   |   |   |   |   |   | I |   |   |   |   |   |   | 06
# ...
