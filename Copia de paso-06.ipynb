# %% [markdown]
# # Paso 6
#
# Crea la clase `FrequencyTable` en el script `ApylabradosModule.py`
#
# * Configura el constructor para que contenga 2 atributos: el array `letters` que contendrá las 26 posibles letras del juego y el array `frequencies`, que tendrá el mismo tamaño que `letters` e inicialmente todas sus entradas valen 0.
# * Construye el método `.showFrequency()` para que muestre la frecuencia del objeto de `FrequencyTable` para aquellos elementos con frecuencia distinta de 0.
# * Crea el método estático `.isSubset()` que recibe dos objetos de la clase `FrequencyTable` y determina si el primer objeto es subconjunto del segundo. Es decir, que las letras del primer objeto están repetidas igual o menos veces que en el segundo objeto.
# * Vuelve a la clase `Pawns` y añade un método `.getFrequency()` que devuelva un objeto de la clase `FrequencyTable` con las apariciones de cada ficha del objeto.
# * Para completar el punto anterior, crea un método en la clase `FrequencyTable` llamado `.update()` que  recibe por parámetro el caracter `c` y se encarga de actualizar la frecuencias de dicho caracter.
# * Aprovecha los métodos `.getFrequency()` y `.showFrequency()` para modificar el método `.showPawns()` de la clase `Pawns` y simplificarlo.
# * Haz lo mismo con la clase `Word`. Crea un método `.getFrequency()` que devuelva un objeto de la clase `FrequencyTable` con las apariciones de sus letras.
# * En el `main`, obtén la tabla de frecuencias de las fichas del jugador, de la palabra que introduce el jugador por teclado y verifica que la tabla de frecuencias de la palabra introducida es subconjunto de la tabla de frecuencias de las fichas del jugador.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class FrequencyTable:

    def __init__(self):
        letters = []
        frequencies = []
        import csv
        with open("/content/drive/MyDrive/Colab Notebooks/datasets/bag_of_pawns.csv", "r") as f:
            reader = csv.reader(f)
            count = 0
            for row in reader:
                if count >= 1:
                    letters.append(row[0])
                count += 1
        self.letters = letters
        frequencies = [0] * len(letters)
        self.frequencies = frequencies
    
    def showFrequency(self):
        for i in range(len(self.frequencies)):
            if self.frequencies[i] != 0:
                print("{}: {}".format(self.letters[i], self.frequencies[i]))

    @staticmethod
    def isSubset(f1, f2):
        for i in range(len(f1.frequencies)):
            if f1.frequencies[i] > f2.frequencies[i]:
                return False
        return True
    
    def update(self, c):
        idx = self.letters.index(c)
        self.frequencies[idx] += 1

# %%
class Pawns:
    
    def __init__(self):
        self.letters = []
    
    def addPawn(self, c):
        self.letters.append(c.upper())
    
    def addPawns(self, c, n):
        for _ in range(n):
            self.addPawn(c)
    
    def createBag(self):
        with open("/content/drive/MyDrive/Colab Notebooks/datasets/bag_of_pawns.csv") as f:
            count = 0
            for line in f:
                if count >= 1:
                    fi_tot = line.split(sep = ',')
                    self.addPawns(fi_tot[0], int(fi_tot[1]))
                count += 1

    def showPawns(self):
        f_pawns = self.getFrequency()
        f_pawns.showFrequency()

    def takeRandomPawn(self):
        from numpy import random
        return self.letters.pop(random.randint(0, len(self.letters) -1 ))
    
    def getFrequency(self):
        f = FrequencyTable()
        for c in self.letters:
            f.update(c)
        return f

# %%
class Word:

    def __init__(self, word = []):
        self.word = word

    def __str__(self):
        return "".join(self.word)
    
    def areEqual(self, w):
        return self.word == w.word
    
    def isEmpty(self):
        return len(self.word) == 0
    
    @classmethod
    def readWord(cls):
        in_word = list(input().upper())
        return cls(in_word)
    
    @staticmethod
    def readWordFromFile(f):
        file_word = list(f.readline()[:-1])
        w = Word(file_word)
        return w

    def getFrequency(self):
        f = FrequencyTable()
        for c in self.word:
            f.update(c)
        return f
