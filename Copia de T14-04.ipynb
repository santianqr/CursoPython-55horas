# %% [markdown]
# # Ejercicio
#
# Vamos a crear la clase `Circle` que por parámetro tome el radio `r` y tenga 4 métodos: el constructor y las propiedad `.diameter()`, `.perimeter()` y `.area()`.
#
# Finalmente vamos a crear la clase `Cylinder` que herede de `Circle` y `Square`. Vamos a modificar la propiedad `.area()` y crear la propiedad `.volume()`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/python-basico/ejercicios/scripts/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python-basico/ejercicios/scripts

# %%
from geometry import *

# %%
s = RegularPolygon(2, 4)
print(s)
# Out:
# Soy un polígono regular de 4 lados de longitud 2

# %%
square = Square(2)
print(square)
# Out:
# Soy un polígono regular de 4 lados de longitud 2

# %%
print(s.perimeter)
print(square.perimeter)
# Out:
# 8
# 8

# %%
print(s.area)
print(square.area)
# Out:
# 4.0
# 4.0

# %%
cube = Cube(2)
print(cube)
# Out:
# Soy un cubo con lados de longitud 2

# %%
print(cube.area)
# Out:
# 24.0

# %%
print(cube.volume)
# Out:
# 8.0

# %%
c = Cylinder(1)

# %%
print(c.diameter)
# Out:
# 2

# %%
print(c.area)
# Out:
# 45.76160291153702
