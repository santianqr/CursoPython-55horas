# %% [markdown]
# # Ejercicio
#
# Dado un string, vamos a comprobar si contiene espacios en blanco y, en caso de ser cierto, contaremos cuántos tiene.
#
# PISTA: Investiga el operador `in`

# %%
proof_string = "Hola a todos, como están?"

if " " in proof_string:
    print("El string de prueba tiene {} espacios en blanco".format(proof_string.count(" ")))
# Out:
# El string de prueba tiene 4 espacios en blanco
